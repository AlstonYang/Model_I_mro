# %%
import pandas as pd
import numpy as np
import torch
import copy
from sklearn import preprocessing

df = pd.read_csv('market.csv')
df
# Out:
#           Date  TS(10Y3M)  TS(5Y3M)     Infla    IndPro  M1 money  M2 money  \
# 0     1962/1/1       1.37      1.26  0.001000   25.3943     145.2     337.5
# 1     1962/2/1       1.29      1.06  0.002330   25.8097     145.7     340.1
# 2     1962/3/1       1.11      0.86  0.001993   25.9482     146.0     343.1
# 3     1962/4/1       1.12      0.90  0.001326   26.0035     146.4     345.5
# 4     1962/5/1       1.20      0.96  0.000993   25.9758     146.8     347.5
# ..         ...        ...       ...       ...       ...       ...       ...
# 703   2020/8/1       0.61      0.17  0.003703  102.6588    5391.2   18404.0
# 704   2020/9/1       0.59      0.18  0.002033  102.5968    5502.5   18648.3
# 705  2020/10/1       0.79      0.29  0.000446  103.6058    5580.4   18812.0
# 706  2020/11/1       0.76      0.28  0.001890  104.0882    6047.6   19086.0
# 707  2020/12/1       0.84      0.27  0.003673  105.7244    6621.3   19188.3
#
#      FedFund  Unemp     S&PClose      S&PVol    Clo3MA   Clo12MA  MarketStatus
# 0       1.50    5.8    68.839996     3840000 -0.024515  0.023770             1
# 1       2.75    5.5    69.959999     3030000 -0.002234  0.032087             1
# 2       2.75    5.6    69.550003     2950000  0.001440  0.020406             1
# 3       2.50    5.6    65.239998     4150000 -0.044103 -0.042747             1
# 4       2.75    5.5    59.630001    10710000 -0.079879 -0.117584             1
# ..       ...    ...          ...         ...       ...       ...           ...
# 703     0.09    8.4  3500.310059  4342290000  0.063739  0.135885             1
# 704     0.09    7.8  3363.000000  4722530000 -0.004483  0.080045             1
# 705     0.09    6.9  3269.959961  4840450000 -0.031914  0.043673             1
# 706     0.09    6.7  3621.629883  6291400000  0.059515  0.141325             1
# 707     0.09    6.7  3756.070068  3172510000  0.058280  0.167586             1
#
# [708 rows x 14 columns]

# %%
import torch.optim as optim
class TwoLayerNet(torch.nn.Module):
    def __init__(self, D_in, H, D_out):
        super(TwoLayerNet, self).__init__()
        self.linear1 = torch.nn.Linear(D_in, H)
        self.linear2 = torch.nn.Linear(H, D_out)
        self.learning_rate = 0.01
        self.matching_accept = False
    
    def forward(self, x, y):
        h_relu = self.linear1(x).clamp(min=0)
        y_pred = self.linear2(h_relu)
        loss = torch.nn.functional.mse_loss(y_pred, y)
        return y_pred, loss
    
    def backward_Adam(self, loss, weight_decay=0):
        optimizer = optim.Adam(self.parameters(), lr=self.learning_rate, weight_decay=0)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        #optimizer.zero_grad()

# %%
# Set up an acceptable SLFN with four hidden nodes
D_in, H, D_out = 12, 4, 1
model = TwoLayerNet(D_in, H, D_out)

print(model)
print(model.state_dict())
# Out:
# TwoLayerNet(
#   (linear1): Linear(in_features=12, out_features=4, bias=True)
#   (linear2): Linear(in_features=4, out_features=1, bias=True)
# )
# OrderedDict([('linear1.weight', tensor([[ 0.2723, -0.1925,  0.2222,  0.2130,  0.1865,  0.0548,  0.1574, -0.0492,
#          -0.1201, -0.2204, -0.1330, -0.1993],
#         [ 0.0138, -0.1791,  0.1294, -0.0224, -0.2030, -0.0647,  0.0367, -0.1841,
#           0.0697, -0.2789,  0.2628,  0.1949],
#         [ 0.0569,  0.1499,  0.0087,  0.1372, -0.1612,  0.2681, -0.0184,  0.0251,
#          -0.1185,  0.0835, -0.1842, -0.1785],
#         [ 0.2313,  0.2058,  0.0942, -0.1411,  0.1421, -0.0322, -0.0474,  0.2260,
#           0.0686,  0.0778,  0.1662,  0.0238]])), ('linear1.bias', tensor([ 0.0304, -0.2251, -0.1314, -0.1876])), ('linear2.weight', tensor([[-0.2321,  0.1389, -0.4302, -0.4130]])), ('linear2.bias', tensor([-0.0926]))])

# %%
### MATCHING MODULE
## Helps tune weights to obtain an acceptable net.

def matching(x, y, model):
    #class1 = 1
    #class2 = 0
    
    for t in range(100):
        # forward
        y_pred, loss = model.forward(x, y)
        
        # learning goal
        alpha = y_pred[torch.where(y == class1)].min()
        beta =  y_pred[torch.where(y == class2)].max()
        
        if torch.gt(alpha, beta):
            model.matching_accept = True
            print("MATCHING MODULE finished: 執行了"+str(t+1)+"次→ Acceptable net.")
            return model
        
        else:
            # backward
            model.backward_Adam(loss)
            
            if t == 99:
                model.matching_accept = False
                print("MATCHING MODULE finished: 執行了"+str(t+1)+"次→ Unacceptable net.")
                return model

# %%
### REGULARIZING MODULE
## Helps further regularize weights while maintaining  an acceptable network.
## Hyperparameters:
## 100
## Optimizer(Adam)
## Learning rate(*1.2 or *0.7)

def regularizing(x, y, model):
    
    y_pred, loss = model(x, y)
    episilon_lr = 0.0001
    model.learning_rate = 0.001
 
    for t in range(100):
        # store weight
        pre_model = copy.deepcopy(model)
        
        while True:
            pre_loss = loss
            
            # backward operation to obtain w'
            model.backward_Adam(loss, weight_decay=0.1)
            
            # forward operation
            y_pred, loss = model(x, y)
            
            # learning goal
            alpha = y_pred[torch.where(y == 1)].min()
            beta =  y_pred[torch.where(y == 0)].max()
            
            if loss <= pre_loss:
                if torch.gt(alpha, beta):
                    model.learning_rate *= 1.2
                    break
                    
                else:
                    # restore weight
                    model = pre_model
                    print('REGULARIZING MODULE finished: 執行了'+str(t+1)+'次→ An acceptable net that has a preference on weights.')
                    return model
                
            else:   
                if model.learning_rate > episilon_lr:
                    # restore weight
                    model = pre_model
                    model.learning_rate *= 0.7
                           
                else:
                    # restore weight
                    model = pre_model
                    print('REGULARIZING MODULE finished: 執行了'+str(t+1)+'次→ An acceptable net that has a preference on weights.')
                    return model
                
        if t >= 99:
            print('REGULARIZING MODULE finished: 執行了'+str(t+1)+'次→ An acceptable net that has a preference on weights.')
            return model

# %%
### REORGANIZING MODULE
## Helps identify and remove the potentially irrelevant hidden node.
## Hyperparameters:
## 100
## optimizer(Adam, one with weight_decay)


def reorganizing(x, y, model):
    k = 1
    # current number of hidden nodes
    p = model.linear1.weight.shape[0]
    
    #alpha = y_pred[torch.where(y == 1)].min()
    #beta =  y_pred[torch.where(y == 0)].max()
    
    
    while True:

        if k > p:
            print('REORGANIZING MODULE finished: Acceptable net with the number of hidden nodes=', p)
            return model
        
        else:
            # 呼叫 regularizing module
            model = regularizing(x, y, model)
            pre_model = copy.deepcopy(model)
            
            
            model.linear1.weight = torch.nn.Parameter(torch.cat([model.linear1.weight[:k-1],model.linear1.weight[k:]]))
            model.linear1.bias = torch.nn.Parameter(torch.cat([model.linear1.bias[:k-1], model.linear1.bias[k:]]))
            model.linear2.weight = torch.nn.Parameter(torch.cat([model.linear2.weight[:,:k-1], model.linear2.weight[:,k:]],1))
            
            # 呼叫 matching module
            model = matching(x, y, model)
            
            
            if model.matching_accept == True:
                print('REORGANIZING MODULE drop the hidden node: %d/%d' %(k, p))
                p = p-1
            
            else:
                model = pre_model
                print('REORGANIZING MODULE cannot drop the hidden node: %d/%d' %(k, p))
                k = k+1

# %%
### CRAMMING MODULE 
def cramming(x, y, model):
    
    y_pred, loss = model(x, y)
    
    sub_data = (x[:-1]-x[-1])
    sub_data = torch.transpose(sub_data,0,1)
    unaccept_data = torch.transpose(x[-1].resize(1,12),0,1)
    
    while True:
        # find m-vector: gamma
        gamma = torch.rand(1,12)
        matmul_subvalue = torch.matmul(gamma, sub_data)
        if 0 not in matmul_subvalue:
            break
    
    while True:
        # find a small number: zeta
        zeta = torch.rand(1) 
        z_value = (zeta+matmul_subvalue)*(zeta-matmul_subvalue)
        if False not in torch.lt(z_value,0):
            break
    
            
    # add three hidden nodes
    # set the weight of input layer to hidden layer
    wih0 = gamma
    wih1 = gamma
    wih2 = gamma
    wih_new = torch.cat([wih0,wih1,wih2],0)
    
    # set the bias of hidden nodes
    matmul_unvalue = torch.matmul(gamma, unaccept_data)
    bh0 = zeta-matmul_unvalue
    bh1 = -matmul_unvalue
    bh2 = -zeta-matmul_unvalue
    bh_new = torch.cat([bh0,bh1,bh2],1)[0]                   
    
    # set the weight of hidden layer to output layer
    gap1 = y_pred[torch.where(y[:-1] == 1)]-y_pred[-1]
    gap2 = y_pred[torch.where(y[:-1] == 0)]-y_pred[-1]
    
    if y[-1] == 1 :
        who0 = min(gap1)/zeta
        who1 = (-2*min(gap1))/zeta
        who2 = min(gap1)/zeta
        
    else:
        who0 = max(gap2)/zeta
        who1 = (-2*max(gap2))/zeta
        who2 = max(gap2)/zeta
    
    wo_new = torch.cat([who0,who1,who2],0)
        
    #model.hidden_node +=3    
    # adjust neural network(add new hidden nodes)
    model.linear1.weight = torch.nn.Parameter(torch.cat([model.linear1.weight, wih_new]))
    model.linear1.bias = torch.nn.Parameter(torch.cat([model.linear1.bias, bh_new]))
    model.linear2.weight = torch.nn.Parameter(torch.cat([model.linear2.weight[0], wo_new]).unsqueeze(0))
    
    #print(model.state_dict())
    print('CRAMMING MODULE finished: The number of hidden nodes=', model.linear1.weight.shape[0])
    return model

# %%
#### 主程式
### INITIALIZING MODULE
## Use the random method to set up an acceptable SLFN with one hidden node 
## through the first two training data {(x1, y1), (x2, y2)}

# Find the first index of class1 and class2
class1 = 1
class2 = 0
first_index_of_class1 = df.index[df['MarketStatus']==class1][0]
first_index_of_class2 = df.index[df['MarketStatus']==class2][0]

# Create x data and y data
x_data = df.iloc[:,1:-1].values
y_data = df.iloc[:,-1].values

# Transform x data to 0-1 range
scaler = preprocessing.MinMaxScaler()
x_data = scaler.fit_transform(x_data)

# Change the data type to tensor
x_data = torch.FloatTensor(x_data)
y_data = torch.FloatTensor(y_data).unsqueeze(1)

# The first two training data
x_ini_data = x_data[[first_index_of_class1, first_index_of_class2]]
y_ini_data = y_data[[first_index_of_class1, first_index_of_class2]]

# Remain data
x_data = torch.cat([x_data[1:first_index_of_class2], x_data[first_index_of_class2+1:]])
y_data = torch.cat([y_data[1:first_index_of_class2], y_data[first_index_of_class2+1:]])

###################################################################################################################

### SELECTING MODULE
## Pick up the first n training data {(xc, yc): c = 1, 2, …, n} and I(n) = {1, 2, …, n}.
x_current = x_ini_data
y_current = y_ini_data

num_train = 500

#for i in range(len(x_data)):
for i in range(num_train-2):   
    print('Stage: %d' %(i+3))
    print(model.state_dict())
    
    x_current = torch.cat([x_current, x_data[i].unsqueeze(0)])
    y_current = torch.cat([y_current, y_data[i].unsqueeze(0)])
    
    y_pred, loss = model(x_current, y_current)

    ### SET THE LEARNING GOAL:SEC
    # define alpha
    if class1 in y_current:
        alpha = y_pred[torch.where(y_current == class1)].min()
    else:
        alpha = 1e6
        
    # define beta
    if class2 in y_current:
        beta = y_pred[torch.where(y_current == class2)].max()
    else:
        beta = -1e6
     
    print('alpha=',alpha)
    print('beta= ',beta)
    print('\n')
    
    # check whether the new data meets the leaning goal:SeC
    if torch.gt(alpha, beta):
        #進入reorganizing module
        model = reorganizing(x_current, y_current, model)
    
    else:
        # save current weight
        pre_model = copy.deepcopy(model)
        
        #進入matching module
        model = matching(x_current, y_current, model)
        
        if model.matching_accept == True:
            #進入reorganizing module
            model = reorganizing(x_current, y_current, model)
            
        else:
            #restore weight
            model = pre_model
            #進入cramming module
            model = cramming(x_current, y_current, model)
            #進入reorganizing module
            model = reorganizing(x_current, y_current, model)
    
    print(model.state_dict())
    print('------------------------------------------------------------------------------------------------------------------------')
# Out:
# Stage: 3
# OrderedDict([('linear1.weight', tensor([[ 0.2723, -0.1925,  0.2222,  0.2130,  0.1865,  0.0548,  0.1574, -0.0492,
#          -0.1201, -0.2204, -0.1330, -0.1993],
#         [ 0.0138, -0.1791,  0.1294, -0.0224, -0.2030, -0.0647,  0.0367, -0.1841,
#           0.0697, -0.2789,  0.2628,  0.1949],
#         [ 0.0569,  0.1499,  0.0087,  0.1372, -0.1612,  0.2681, -0.0184,  0.0251,
#          -0.1185,  0.0835, -0.1842, -0.1785],
#         [ 0.2313,  0.2058,  0.0942, -0.1411,  0.1421, -0.0322, -0.0474,  0.2260,
#           0.0686,  0.0778,  0.1662,  0.0238]])), ('linear1.bias', tensor([ 0.0304, -0.2251, -0.1314, -0.1876])), ('linear2.weight', tensor([[-0.2321,  0.1389, -0.4302, -0.4130]])), ('linear2.bias', tensor([-0.0926]))])
# alpha= tensor(-0.1909, grad_fn=<MinBackward1>)
# beta=  tensor(-0.1497, grad_fn=<MaxBackward1>)
#
#
# MATCHING MODULE finished: 執行了32次→ Acceptable net.
# REGULARIZING MODULE finished: 執行了100次→ An acceptable net that has a preference on weights.
# MATCHING MODULE finished: 執行了1次→ Acceptable net.
# REORGANIZING MODULE drop the hidden node: 1/4
# REGULARIZING MODULE finished: 執行了100次→ An acceptable net that has a preference on weights.
# MATCHING MODULE finished: 執行了100次→ Unacceptable net.
# REORGANIZING MODULE cannot drop the hidden node: 1/3
# REGULARIZING MODULE finished: 執行了100次→ An acceptable net that has a preference on weights.
# MATCHING MODULE finished: 執行了1次→ Acceptable net.
# REORGANIZING MODULE drop the hidden node: 2/3
# REGULARIZING MODULE finished: 執行了100次→ An acceptable net that has a preference on weights.
# MATCHING MODULE finished: 執行了1次→ Acceptable net.
# REORGANIZING MODULE drop the hidden node: 2/2
# REORGANIZING MODULE finished: Acceptable net with the number of hidden nodes= 1
# OrderedDict([('linear1.weight', tensor([[ 0.6316,  0.4107, -0.1507, -2.5340, -2.7346, -2.5963, -2.0341,  2.3605,
#          -2.1418, -2.7441,  0.3862,  0.3970]])), ('linear1.bias', tensor([-0.0936])), ('linear2.weight', tensor([[0.8965]])), ('linear2.bias', tensor([0.0116]))])
# ------------------------------------------------------------------------------------------------------------------------
# Stage: 4
# OrderedDict([('linear1.weight', tensor([[ 0.6316,  0.4107, -0.1507, -2.5340, -2.7346, -2.5963, -2.0341,  2.3605,
#          -2.1418, -2.7441,  0.3862,  0.3970]])), ('linear1.bias', tensor([-0.0936])), ('linear2.weight', tensor([[0.8965]])), ('linear2.bias', tensor([0.0116]))])
# alpha= tensor(0.8959, grad_fn=<MinBackward1>)
# beta=  tensor(0.0177, grad_fn=<MaxBackward1>)
#
#
# REGULARIZING MODULE finished: 執行了100次→ An acceptable net that has a preference on weights.
# MATCHING MODULE finished: 執行了100次→ Unacceptable net.
# REORGANIZING MODULE cannot drop the hidden node: 1/1
# REORGANIZING MODULE finished: Acceptable net with the number of hidden nodes= 1
# OrderedDict([('linear1.weight', tensor([[ 0.6283,  0.3896, -0.1571, -2.5954, -2.7960, -2.6577, -1.9727,  2.3933,
#          -2.1959, -2.8055,  0.4306,  0.3937]])), ('linear1.bias', tensor([-0.0969])), ('linear2.weight', tensor([[0.9112]])), ('linear2.bias', tensor([0.0083]))])
# ------------------------------------------------------------------------------------------------------------------------
# Stage: 5
# OrderedDict([('linear1.weight', tensor([[ 0.6283,  0.3896, -0.1571, -2.5954, -2.7960, -2.6577, -1.9727,  2.3933,
#          -2.1959, -2.8055,  0.4306,  0.3937]])), ('linear1.bias', tensor([-0.0969])), ('linear2.weight', tensor([[0.9112]])), ('linear2.bias', tensor([0.0083]))])
# alpha= tensor(0.8443, grad_fn=<MinBackward1>)
# beta=  tensor(0.0279, grad_fn=<MaxBackward1>)
#
#
# REGULARIZING MODULE finished: 執行了100次→ An acceptable net that has a preference on weights.
# MATCHING MODULE finished: 執行了100次→ Unacceptable net.
# REORGANIZING MODULE cannot drop the hidden node: 1/1
# REORGANIZING MODULE finished: Acceptable net with the number of hidden nodes= 1
# OrderedDict([('linear1.weight', tensor([[ 0.6354,  0.3967, -0.1499, -2.6839, -2.8845, -2.7462, -1.9320,  2.4776,
#          -2.2772, -2.8939,  0.4377,  0.3753]])), ('linear1.bias', tensor([-0.0898])), ('linear2.weight', tensor([[0.9184]])), ('linear2.bias', tensor([0.0154]))])
# ------------------------------------------------------------------------------------------------------------------------
# Stage: 6
# OrderedDict([('linear1.weight', tensor([[ 0.6354,  0.3967, -0.1499, -2.6839, -2.8845, -2.7462, -1.9320,  2.4776,
#          -2.2772, -2.8939,  0.4377,  0.3753]])), ('linear1.bias', tensor([-0.0898])), ('linear2.weight', tensor([[0.9184]])), ('linear2.bias', tensor([0.0154]))])
# alpha= tensor(0.7592, grad_fn=<MinBackward1>)
# beta=  tensor(0.0444, grad_fn=<MaxBackward1>)
#
#
# REGULARIZING MODULE finished: 執行了84次→ An acceptable net that has a preference on weights.
# MATCHING MODULE finished: 執行了100次→ Unacceptable net.
# REORGANIZING MODULE cannot drop the hidden node: 1/1
# REORGANIZING MODULE finished: Acceptable net with the number of hidden nodes= 1
# OrderedDict([('linear1.weight', tensor([[ 0.6895,  0.3999, -0.1753, -2.7614, -2.9619, -2.8236, -1.8597,  2.5530,
#          -2.3805, -2.7906,  0.3590,  0.2966]])), ('linear1.bias', tensor([-0.0357])), ('linear2.weight', tensor([[0.9060]])), ('linear2.bias', tensor([0.0652]))])
# ------------------------------------------------------------------------------------------------------------------------
# Stage: 7
# OrderedDict([('linear1.weight', tensor([[ 0.6895,  0.3999, -0.1753, -2.7614, -2.9619, -2.8236, -1.8597,  2.5530,
#          -2.3805, -2.7906,  0.3590,  0.2966]])), ('linear1.bias', tensor([-0.0357])), ('linear2.weight', tensor([[0.9060]])), ('linear2.bias', tensor([0.0652]))])
# alpha= tensor(0.7930, grad_fn=<MinBackward1>)
# beta=  tensor(0.0652, grad_fn=<MaxBackward1>)
#
#
# REGULARIZING MODULE finished: 執行了100次→ An acceptable net that has a preference on weights.
# MATCHING MODULE finished: 執行了100次→ Unacceptable net.
# REORGANIZING MODULE cannot drop the hidden node: 1/1
# REORGANIZING MODULE finished: Acceptable net with the number of hidden nodes= 1
# OrderedDict([('linear1.weight', tensor([[ 0.7516,  0.4176, -0.1679, -2.7689, -2.9694, -2.8311, -1.7914,  2.6244,
#          -2.4581, -2.7130,  0.2834,  0.2209]])), ('linear1.bias', tensor([0.0087])), ('linear2.weight', tensor([[0.8934]])), ('linear2.bias', tensor([0.0793]))])
# ------------------------------------------------------------------------------------------------------------------------
# Stage: 8
# OrderedDict([('linear1.weight', tensor([[ 0.7516,  0.4176, -0.1679, -2.7689, -2.9694, -2.8311, -1.7914,  2.6244,
#          -2.4581, -2.7130,  0.2834,  0.2209]])), ('linear1.bias', tensor([0.0087])), ('linear2.weight', tensor([[0.8934]])), ('linear2.bias', tensor([0.0793]))])
# alpha= tensor(0.8526, grad_fn=<MinBackward1>)
# beta=  tensor(0.0794, grad_fn=<MaxBackward1>)
#
#
# REGULARIZING MODULE finished: 執行了27次→ An acceptable net that has a preference on weights.
# MATCHING MODULE finished: 執行了100次→ Unacceptable net.
# REORGANIZING MODULE cannot drop the hidden node: 1/1
# REORGANIZING MODULE finished: Acceptable net with the number of hidden nodes= 1
# OrderedDict([('linear1.weight', tensor([[ 0.7562,  0.4202, -0.1677, -2.7707, -2.9712, -2.8329, -1.7847,  2.6311,
#          -2.4648, -2.7063,  0.2791,  0.2142]])), ('linear1.bias', tensor([0.0113])), ('linear2.weight', tensor([[0.8961]])), ('linear2.bias', tensor([0.0819]))])
# ------------------------------------------------------------------------------------------------------------------------
# Stage: 9
# OrderedDict([('linear1.weight', tensor([[ 0.7562,  0.4202, -0.1677, -2.7707, -2.9712, -2.8329, -1.7847,  2.6311,
#          -2.4648, -2.7063,  0.2791,  0.2142]])), ('linear1.bias', tensor([0.0113])), ('linear2.weight', tensor([[0.8961]])), ('linear2.bias', tensor([0.0819]))])
# alpha= tensor(0.8619, grad_fn=<MinBackward1>)
# beta=  tensor(0.0820, grad_fn=<MaxBackward1>)
#
#
# REGULARIZING MODULE finished: 執行了64次→ An acceptable net that has a preference on weights.
# MATCHING MODULE finished: 執行了100次→ Unacceptable net.
# REORGANIZING MODULE cannot drop the hidden node: 1/1
# REORGANIZING MODULE finished: Acceptable net with the number of hidden nodes= 1
# OrderedDict([('linear1.weight', tensor([[ 0.7650,  0.4231, -0.1648, -2.7677, -2.9683, -2.8300, -1.7751,  2.6407,
#          -2.4744, -2.6967,  0.2696,  0.2047]])), ('linear1.bias', tensor([0.0143])), ('linear2.weight', tensor([[0.8941]])), ('linear2.bias', tensor([0.0794]))])
# ------------------------------------------------------------------------------------------------------------------------
# Stage: 10
# OrderedDict([('linear1.weight', tensor([[ 0.7650,  0.4231, -0.1648, -2.7677, -2.9683, -2.8300, -1.7751,  2.6407,
#          -2.4744, -2.6967,  0.2696,  0.2047]])), ('linear1.bias', tensor([0.0143])), ('linear2.weight', tensor([[0.8941]])), ('linear2.bias', tensor([0.0794]))])
# alpha= tensor(0.8641, grad_fn=<MinBackward1>)
# beta=  tensor(0.0795, grad_fn=<MaxBackward1>)
#
#
# REGULARIZING MODULE finished: 執行了100次→ An acceptable net that has a preference on weights.
# MATCHING MODULE finished: 執行了100次→ Unacceptable net.
# REORGANIZING MODULE cannot drop the hidden node: 1/1
# REORGANIZING MODULE finished: Acceptable net with the number of hidden nodes= 1
# OrderedDict([('linear1.weight', tensor([[ 0.7830,  0.4382, -0.1521, -2.7570, -2.9576, -2.8193, -1.7285,  2.6873,
#          -2.5260, -2.6452,  0.2464,  0.1530]])), ('linear1.bias', tensor([0.0294])), ('linear2.weight', tensor([[0.8936]])), ('linear2.bias', tensor([0.0761]))])
# ------------------------------------------------------------------------------------------------------------------------
# Stage: 11
# OrderedDict([('linear1.weight', tensor([[ 0.7830,  0.4382, -0.1521, -2.7570, -2.9576, -2.8193, -1.7285,  2.6873,
#          -2.5260, -2.6452,  0.2464,  0.1530]])), ('linear1.bias', tensor([0.0294])), ('linear2.weight', tensor([[0.8936]])), ('linear2.bias', tensor([0.0761]))])
# alpha= tensor(0.8862, grad_fn=<MinBackward1>)
# beta=  tensor(0.0772, grad_fn=<MaxBackward1>)
#
#
# REGULARIZING MODULE finished: 執行了100次→ An acceptable net that has a preference on weights.
# MATCHING MODULE finished: 執行了100次→ Unacceptable net.
# REORGANIZING MODULE cannot drop the hidden node: 1/1
# REORGANIZING MODULE finished: Acceptable net with the number of hidden nodes= 1
# OrderedDict([('linear1.weight', tensor([[ 0.7929,  0.4481, -0.1446, -2.7516, -2.9522, -2.8138, -1.6942,  2.7167,
#          -2.5637, -2.6076,  0.2339,  0.1154]])), ('linear1.bias', tensor([0.0392])), ('linear2.weight', tensor([[0.8946]])), ('linear2.bias', tensor([0.0749]))])
# ------------------------------------------------------------------------------------------------------------------------
# Stage: 12
# OrderedDict([('linear1.weight', tensor([[ 0.7929,  0.4481, -0.1446, -2.7516, -2.9522, -2.8138, -1.6942,  2.7167,
#          -2.5637, -2.6076,  0.2339,  0.1154]])), ('linear1.bias', tensor([0.0392])), ('linear2.weight', tensor([[0.8946]])), ('linear2.bias', tensor([0.0749]))])
# alpha= tensor(0.9017, grad_fn=<MinBackward1>)
# beta=  tensor(0.0754, grad_fn=<MaxBackward1>)
#
#
# REGULARIZING MODULE finished: 執行了100次→ An acceptable net that has a preference on weights.
# MATCHING MODULE finished: 執行了100次→ Unacceptable net.
# REORGANIZING MODULE cannot drop the hidden node: 1/1
# REORGANIZING MODULE finished: Acceptable net with the number of hidden nodes= 1
# OrderedDict([('linear1.weight', tensor([[ 0.8109,  0.4570, -0.1357, -2.7426, -2.9432, -2.8049, -1.6705,  2.7386,
#          -2.5894, -2.5820,  0.2082,  0.0897]])), ('linear1.bias', tensor([0.0482])), ('linear2.weight', tensor([[0.8935]])), ('linear2.bias', tensor([0.0655]))])
# ------------------------------------------------------------------------------------------------------------------------
# Stage: 13
# OrderedDict([('linear1.weight', tensor([[ 0.8109,  0.4570, -0.1357, -2.7426, -2.9432, -2.8049, -1.6705,  2.7386,
#          -2.5894, -2.5820,  0.2082,  0.0897]])), ('linear1.bias', tensor([0.0482])), ('linear2.weight', tensor([[0.8935]])), ('linear2.bias', tensor([0.0655]))])
# alpha= tensor(0.9069, grad_fn=<MinBackward1>)
# beta=  tensor(0.0655, grad_fn=<MaxBackward1>)
#
#
# REGULARIZING MODULE finished: 執行了100次→ An acceptable net that has a preference on weights.
# MATCHING MODULE finished: 執行了100次→ Unacceptable net.
# REORGANIZING MODULE cannot drop the hidden node: 1/1
# REORGANIZING MODULE finished: Acceptable net with the number of hidden nodes= 1
# OrderedDict([('linear1.weight', tensor([[ 0.8156,  0.4593, -0.1334, -2.7423, -2.9429, -2.8046, -1.6582,  2.7494,
#          -2.6017, -2.5696,  0.2021,  0.0773]])), ('linear1.bias', tensor([0.0529])), ('linear2.weight', tensor([[0.8947]])), ('linear2.bias', tensor([0.0659]))])
# ------------------------------------------------------------------------------------------------------------------------
# Stage: 14
# OrderedDict([('linear1.weight', tensor([[ 0.8156,  0.4593, -0.1334, -2.7423, -2.9429, -2.8046, -1.6582,  2.7494,
#          -2.6017, -2.5696,  0.2021,  0.0773]])), ('linear1.bias', tensor([0.0529])), ('linear2.weight', tensor([[0.8947]])), ('linear2.bias', tensor([0.0659]))])
# alpha= tensor(0.9149, grad_fn=<MinBackward1>)
# beta=  tensor(0.0661, grad_fn=<MaxBackward1>)
#
#
# REGULARIZING MODULE finished: 執行了70次→ An acceptable net that has a preference on weights.
# MATCHING MODULE finished: 執行了100次→ Unacceptable net.
# REORGANIZING MODULE cannot drop the hidden node: 1/1
# REORGANIZING MODULE finished: Acceptable net with the number of hidden nodes= 1
# OrderedDict([('linear1.weight', tensor([[ 0.8189,  0.4606, -0.1321, -2.7410, -2.9416, -2.8032, -1.6458,  2.7565,
#          -2.6141, -2.5573,  0.2002,  0.0650]])), ('linear1.bias', tensor([0.0562])), ('linear2.weight', tensor([[0.8949]])), ('linear2.bias', tensor([0.0652]))])
# ------------------------------------------------------------------------------------------------------------------------
# Stage: 15
# OrderedDict([('linear1.weight', tensor([[ 0.8189,  0.4606, -0.1321, -2.7410, -2.9416, -2.8032, -1.6458,  2.7565,
#          -2.6141, -2.5573,  0.2002,  0.0650]])), ('linear1.bias', tensor([0.0562])), ('linear2.weight', tensor([[0.8949]])), ('linear2.bias', tensor([0.0652]))])
# alpha= tensor(0.9187, grad_fn=<MinBackward1>)
# beta=  tensor(0.0653, grad_fn=<MaxBackward1>)
#
#
# REGULARIZING MODULE finished: 執行了19次→ An acceptable net that has a preference on weights.
# MATCHING MODULE finished: 執行了100次→ Unacceptable net.
# REORGANIZING MODULE cannot drop the hidden node: 1/1
# REORGANIZING MODULE finished: Acceptable net with the number of hidden nodes= 1
# OrderedDict([('linear1.weight', tensor([[ 0.8190,  0.4607, -0.1320, -2.7410, -2.9416, -2.8032, -1.6455,  2.7568,
#          -2.6144, -2.5570,  0.2003,  0.0646]])), ('linear1.bias', tensor([0.0562])), ('linear2.weight', tensor([[0.8945]])), ('linear2.bias', tensor([0.0649]))])
# ------------------------------------------------------------------------------------------------------------------------
# Stage: 16
# OrderedDict([('linear1.weight', tensor([[ 0.8190,  0.4607, -0.1320, -2.7410, -2.9416, -2.8032, -1.6455,  2.7568,
#          -2.6144, -2.5570,  0.2003,  0.0646]])), ('linear1.bias', tensor([0.0562])), ('linear2.weight', tensor([[0.8945]])), ('linear2.bias', tensor([0.0649]))])
# alpha= tensor(0.9181, grad_fn=<MinBackward1>)
# beta=  tensor(0.0649, grad_fn=<MaxBackward1>)
#
#
# REGULARIZING MODULE finished: 執行了17次→ An acceptable net that has a preference on weights.
# MATCHING MODULE finished: 執行了100次→ Unacceptable net.
# REORGANIZING MODULE cannot drop the hidden node: 1/1
# REORGANIZING MODULE finished: Acceptable net with the number of hidden nodes= 1
# OrderedDict([('linear1.weight', tensor([[ 0.8200,  0.4617, -0.1330, -2.7420, -2.9426, -2.8042, -1.6445,  2.7578,
#          -2.6154, -2.5560,  0.1993,  0.0636]])), ('linear1.bias', tensor([0.0572])), ('linear2.weight', tensor([[0.8955]])), ('linear2.bias', tensor([0.0659]))])
# ------------------------------------------------------------------------------------------------------------------------
# Stage: 17
# OrderedDict([('linear1.weight', tensor([[ 0.8200,  0.4617, -0.1330, -2.7420, -2.9426, -2.8042, -1.6445,  2.7578,
#          -2.6154, -2.5560,  0.1993,  0.0636]])), ('linear1.bias', tensor([0.0572])), ('linear2.weight', tensor([[0.8955]])), ('linear2.bias', tensor([0.0659]))])
# alpha= tensor(0.9211, grad_fn=<MinBackward1>)
# beta=  tensor(0.0659, grad_fn=<MaxBackward1>)
#
#
# REGULARIZING MODULE finished: 執行了21次→ An acceptable net that has a preference on weights.
# MATCHING MODULE finished: 執行了100次→ Unacceptable net.
# REORGANIZING MODULE cannot drop the hidden node: 1/1
# REORGANIZING MODULE finished: Acceptable net with the number of hidden nodes= 1
# OrderedDict([('linear1.weight', tensor([[ 0.8203,  0.4620, -0.1327, -2.7417, -2.9423, -2.8039, -1.6438,  2.7581,
#          -2.6161, -2.5553,  0.1986,  0.0630]])), ('linear1.bias', tensor([0.0575])), ('linear2.weight', tensor([[0.8949]])), ('linear2.bias', tensor([0.0652]))])
# ------------------------------------------------------------------------------------------------------------------------
# Stage: 18
# OrderedDict([('linear1.weight', tensor([[ 0.8203,  0.4620, -0.1327, -2.7417, -2.9423, -2.8039, -1.6438,  2.7581,
#          -2.6161, -2.5553,  0.1986,  0.0630]])), ('linear1.bias', tensor([0.0575])), ('linear2.weight', tensor([[0.8949]])), ('linear2.bias', tensor([0.0652]))])
# alpha= tensor(0.9203, grad_fn=<MinBackward1>)
# beta=  tensor(0.0653, grad_fn=<MaxBackward1>)
#
#
# REGULARIZING MODULE finished: 執行了15次→ An acceptable net that has a preference on weights.
# MATCHING MODULE finished: 執行了100次→ Unacceptable net.
# REORGANIZING MODULE cannot drop the hidden node: 1/1
# REORGANIZING MODULE finished: Acceptable net with the number of hidden nodes= 1
# OrderedDict([('linear1.weight', tensor([[ 0.8203,  0.4620, -0.1327, -2.7417, -2.9423, -2.8039, -1.6438,  2.7581,
#          -2.6161, -2.5553,  0.1986,  0.0630]])), ('linear1.bias', tensor([0.0575])), ('linear2.weight', tensor([[0.8949]])), ('linear2.bias', tensor([0.0652]))])
# ------------------------------------------------------------------------------------------------------------------------
# Stage: 19
# OrderedDict([('linear1.weight', tensor([[ 0.8203,  0.4620, -0.1327, -2.7417, -2.9423, -2.8039, -1.6438,  2.7581,
#          -2.6161, -2.5553,  0.1986,  0.0630]])), ('linear1.bias', tensor([0.0575])), ('linear2.weight', tensor([[0.8949]])), ('linear2.bias', tensor([0.0652]))])
# alpha= tensor(0.9095, grad_fn=<MinBackward1>)
# beta=  tensor(0.0653, grad_fn=<MaxBackward1>)
#
#
# REGULARIZING MODULE finished: 執行了100次→ An acceptable net that has a preference on weights.
# MATCHING MODULE finished: 執行了100次→ Unacceptable net.
# REORGANIZING MODULE cannot drop the hidden node: 1/1
# REORGANIZING MODULE finished: Acceptable net with the number of hidden nodes= 1
# OrderedDict([('linear1.weight', tensor([[ 0.8206,  0.4609, -0.1338, -2.7459, -2.9466, -2.8082, -1.6227,  2.7771,
#          -2.6372, -2.5520,  0.1963,  0.0587]])), ('linear1.bias', tensor([0.0579])), ('linear2.weight', tensor([[0.8953]])), ('linear2.bias', tensor([0.0656]))])
# ------------------------------------------------------------------------------------------------------------------------
# Stage: 20
# OrderedDict([('linear1.weight', tensor([[ 0.8206,  0.4609, -0.1338, -2.7459, -2.9466, -2.8082, -1.6227,  2.7771,
#          -2.6372, -2.5520,  0.1963,  0.0587]])), ('linear1.bias', tensor([0.0579])), ('linear2.weight', tensor([[0.8953]])), ('linear2.bias', tensor([0.0656]))])
# alpha= tensor(0.8331, grad_fn=<MinBackward1>)
# beta=  tensor(0.0656, grad_fn=<MaxBackward1>)
#
#
# REGULARIZING MODULE finished: 執行了100次→ An acceptable net that has a preference on weights.
# MATCHING MODULE finished: 執行了100次→ Unacceptable net.
# REORGANIZING MODULE cannot drop the hidden node: 1/1
# REORGANIZING MODULE finished: Acceptable net with the number of hidden nodes= 1
# OrderedDict([('linear1.weight', tensor([[ 0.8235,  0.4637, -0.1310, -2.7815, -2.9845, -2.7705, -1.5828,  2.7936,
#          -2.6751, -2.5501,  0.1809,  0.0615]])), ('linear1.bias', tensor([0.0607])), ('linear2.weight', tensor([[0.8981]])), ('linear2.bias', tensor([0.0684]))])
# ------------------------------------------------------------------------------------------------------------------------
# Stage: 21
# OrderedDict([('linear1.weight', tensor([[ 0.8235,  0.4637, -0.1310, -2.7815, -2.9845, -2.7705, -1.5828,  2.7936,
#          -2.6751, -2.5501,  0.1809,  0.0615]])), ('linear1.bias', tensor([0.0607])), ('linear2.weight', tensor([[0.8981]])), ('linear2.bias', tensor([0.0684]))])
# alpha= tensor(0.8113, grad_fn=<MinBackward1>)
# beta=  tensor(0.0719, grad_fn=<MaxBackward1>)
#
#
# REGULARIZING MODULE finished: 執行了100次→ An acceptable net that has a preference on weights.
# MATCHING MODULE finished: 執行了100次→ Unacceptable net.
# REORGANIZING MODULE cannot drop the hidden node: 1/1
# REORGANIZING MODULE finished: Acceptable net with the number of hidden nodes= 1
# OrderedDict([('linear1.weight', tensor([[ 0.8255,  0.4558, -0.1289, -2.7754, -2.9591, -2.7360, -1.5483,  2.7957,
#          -2.7096, -2.5506,  0.1830,  0.0636]])), ('linear1.bias', tensor([0.0628])), ('linear2.weight', tensor([[0.8978]])), ('linear2.bias', tensor([0.0705]))])
# ------------------------------------------------------------------------------------------------------------------------
# Stage: 22
# OrderedDict([('linear1.weight', tensor([[ 0.8255,  0.4558, -0.1289, -2.7754, -2.9591, -2.7360, -1.5483,  2.7957,
#          -2.7096, -2.5506,  0.1830,  0.0636]])), ('linear1.bias', tensor([0.0628])), ('linear2.weight', tensor([[0.8978]])), ('linear2.bias', tensor([0.0705]))])
# alpha= tensor(0.8222, grad_fn=<MinBackward1>)
# beta=  tensor(0.0847, grad_fn=<MaxBackward1>)
#
#
# REGULARIZING MODULE finished: 執行了100次→ An acceptable net that has a preference on weights.
# MATCHING MODULE finished: 執行了100次→ Unacceptable net.
# REORGANIZING MODULE cannot drop the hidden node: 1/1
# REORGANIZING MODULE finished: Acceptable net with the number of hidden nodes= 1
# OrderedDict([('linear1.weight', tensor([[ 0.8077,  0.4345, -0.1385, -2.7520, -2.9341, -2.6872, -1.4995,  2.8123,
#          -2.7564, -2.5972,  0.1810,  0.0870]])), ('linear1.bias', tensor([0.0729])), ('linear2.weight', tensor([[0.8860]])), ('linear2.bias', tensor([0.0806]))])
# ------------------------------------------------------------------------------------------------------------------------
# Stage: 23
# OrderedDict([('linear1.weight', tensor([[ 0.8077,  0.4345, -0.1385, -2.7520, -2.9341, -2.6872, -1.4995,  2.8123,
#          -2.7564, -2.5972,  0.1810,  0.0870]])), ('linear1.bias', tensor([0.0729])), ('linear2.weight', tensor([[0.8860]])), ('linear2.bias', tensor([0.0806]))])
# alpha= tensor(0.8376, grad_fn=<MinBackward1>)
# beta=  tensor(0.1089, grad_fn=<MaxBackward1>)
#
#
# REGULARIZING MODULE finished: 執行了100次→ An acceptable net that has a preference on weights.
# MATCHING MODULE finished: 執行了100次→ Unacceptable net.
# REORGANIZING MODULE cannot drop the hidden node: 1/1
# REORGANIZING MODULE finished: Acceptable net with the number of hidden nodes= 1
# OrderedDict([('linear1.weight', tensor([[ 0.7933,  0.4179, -0.1385, -2.7223, -2.8863, -2.6375, -1.4498,  2.8160,
#          -2.8020, -2.6446,  0.1809,  0.1104]])), ('linear1.bias', tensor([0.0729])), ('linear2.weight', tensor([[0.8859]])), ('linear2.bias', tensor([0.0806]))])
# ------------------------------------------------------------------------------------------------------------------------
# Stage: 24
# OrderedDict([('linear1.weight', tensor([[ 0.7933,  0.4179, -0.1385, -2.7223, -2.8863, -2.6375, -1.4498,  2.8160,
#          -2.8020, -2.6446,  0.1809,  0.1104]])), ('linear1.bias', tensor([0.0729])), ('linear2.weight', tensor([[0.8859]])), ('linear2.bias', tensor([0.0806]))])
# alpha= tensor(0.8507, grad_fn=<MinBackward1>)
# beta=  tensor(0.1239, grad_fn=<MaxBackward1>)
#
#
# REGULARIZING MODULE finished: 執行了100次→ An acceptable net that has a preference on weights.
# MATCHING MODULE finished: 執行了100次→ Unacceptable net.
# REORGANIZING MODULE cannot drop the hidden node: 1/1
# REORGANIZING MODULE finished: Acceptable net with the number of hidden nodes= 1
# OrderedDict([('linear1.weight', tensor([[ 0.7803,  0.4049, -0.1387, -2.6748, -2.8316, -2.5827, -1.3949,  2.8332,
#          -2.8178, -2.6987,  0.1807,  0.1214]])), ('linear1.bias', tensor([0.0727])), ('linear2.weight', tensor([[0.8858]])), ('linear2.bias', tensor([0.0804]))])
# ------------------------------------------------------------------------------------------------------------------------
# Stage: 25
# OrderedDict([('linear1.weight', tensor([[ 0.7803,  0.4049, -0.1387, -2.6748, -2.8316, -2.5827, -1.3949,  2.8332,
#          -2.8178, -2.6987,  0.1807,  0.1214]])), ('linear1.bias', tensor([0.0727])), ('linear2.weight', tensor([[0.8858]])), ('linear2.bias', tensor([0.0804]))])
# alpha= tensor(0.8543, grad_fn=<MinBackward1>)
# beta=  tensor(0.1366, grad_fn=<MaxBackward1>)
#
#
# REGULARIZING MODULE finished: 執行了100次→ An acceptable net that has a preference on weights.
# MATCHING MODULE finished: 執行了100次→ Unacceptable net.
# REORGANIZING MODULE cannot drop the hidden node: 1/1
# REORGANIZING MODULE finished: Acceptable net with the number of hidden nodes= 1
# OrderedDict([('linear1.weight', tensor([[ 0.7585,  0.3858, -0.1395, -2.6230, -2.7724, -2.5234, -1.3356,  2.8529,
#          -2.8186, -2.6841,  0.1799,  0.1363]])), ('linear1.bias', tensor([0.0719])), ('linear2.weight', tensor([[0.8850]])), ('linear2.bias', tensor([0.0796]))])
# ------------------------------------------------------------------------------------------------------------------------
# Stage: 26
# OrderedDict([('linear1.weight', tensor([[ 0.7585,  0.3858, -0.1395, -2.6230, -2.7724, -2.5234, -1.3356,  2.8529,
#          -2.8186, -2.6841,  0.1799,  0.1363]])), ('linear1.bias', tensor([0.0719])), ('linear2.weight', tensor([[0.8850]])), ('linear2.bias', tensor([0.0796]))])
# alpha= tensor(0.8589, grad_fn=<MinBackward1>)
# beta=  tensor(0.1462, grad_fn=<MaxBackward1>)
#
#
# REGULARIZING MODULE finished: 執行了100次→ An acceptable net that has a preference on weights.
# MATCHING MODULE finished: 執行了100次→ Unacceptable net.
# REORGANIZING MODULE cannot drop the hidden node: 1/1
# REORGANIZING MODULE finished: Acceptable net with the number of hidden nodes= 1
# OrderedDict([('linear1.weight', tensor([[ 0.7240,  0.3642, -0.1359, -2.5641, -2.7136, -2.4646, -1.2768,  2.8855,
#          -2.8150, -2.6806,  0.1835,  0.1456]])), ('linear1.bias', tensor([0.0755])), ('linear2.weight', tensor([[0.8886]])), ('linear2.bias', tensor([0.0832]))])
# ------------------------------------------------------------------------------------------------------------------------
# Stage: 27
# OrderedDict([('linear1.weight', tensor([[ 0.7240,  0.3642, -0.1359, -2.5641, -2.7136, -2.4646, -1.2768,  2.8855,
#          -2.8150, -2.6806,  0.1835,  0.1456]])), ('linear1.bias', tensor([0.0755])), ('linear2.weight', tensor([[0.8886]])), ('linear2.bias', tensor([0.0832]))])
# alpha= tensor(0.8346, grad_fn=<MinBackward1>)
# beta=  tensor(0.1625, grad_fn=<MaxBackward1>)
#
#
# REGULARIZING MODULE finished: 執行了100次→ An acceptable net that has a preference on weights.
# MATCHING MODULE finished: 執行了100次→ Unacceptable net.
# REORGANIZING MODULE cannot drop the hidden node: 1/1
# REORGANIZING MODULE finished: Acceptable net with the number of hidden nodes= 1
# OrderedDict([('linear1.weight', tensor([[ 0.6913,  0.3453, -0.1345, -2.5029, -2.6524, -2.4033, -1.2155,  2.9023,
#          -2.7747, -2.6790,  0.1849,  0.1608]])), ('linear1.bias', tensor([0.0769])), ('linear2.weight', tensor([[0.8899]])), ('linear2.bias', tensor([0.0846]))])
# ------------------------------------------------------------------------------------------------------------------------
# Stage: 28
# OrderedDict([('linear1.weight', tensor([[ 0.6913,  0.3453, -0.1345, -2.5029, -2.6524, -2.4033, -1.2155,  2.9023,
#          -2.7747, -2.6790,  0.1849,  0.1608]])), ('linear1.bias', tensor([0.0769])), ('linear2.weight', tensor([[0.8899]])), ('linear2.bias', tensor([0.0846]))])
# alpha= tensor(0.8455, grad_fn=<MinBackward1>)
# beta=  tensor(0.1772, grad_fn=<MaxBackward1>)
#
#
# REGULARIZING MODULE finished: 執行了100次→ An acceptable net that has a preference on weights.
# MATCHING MODULE finished: 執行了100次→ Unacceptable net.
# REORGANIZING MODULE cannot drop the hidden node: 1/1
# REORGANIZING MODULE finished: Acceptable net with the number of hidden nodes= 1
# OrderedDict([('linear1.weight', tensor([[ 0.6624,  0.3327, -0.1332, -2.4429, -2.5924, -2.3433, -1.1555,  2.9176,
#          -2.7147, -2.6752,  0.1862,  0.1701]])), ('linear1.bias', tensor([0.0782])), ('linear2.weight', tensor([[0.8912]])), ('linear2.bias', tensor([0.0859]))])
# ------------------------------------------------------------------------------------------------------------------------
# Stage: 29
# OrderedDict([('linear1.weight', tensor([[ 0.6624,  0.3327, -0.1332, -2.4429, -2.5924, -2.3433, -1.1555,  2.9176,
#          -2.7147, -2.6752,  0.1862,  0.1701]])), ('linear1.bias', tensor([0.0782])), ('linear2.weight', tensor([[0.8912]])), ('linear2.bias', tensor([0.0859]))])
# alpha= tensor(0.8358, grad_fn=<MinBackward1>)
# beta=  tensor(0.1915, grad_fn=<MaxBackward1>)
#
#
# REGULARIZING MODULE finished: 執行了100次→ An acceptable net that has a preference on weights.
# MATCHING MODULE finished: 執行了100次→ Unacceptable net.
# REORGANIZING MODULE cannot drop the hidden node: 1/1
# REORGANIZING MODULE finished: Acceptable net with the number of hidden nodes= 1
# OrderedDict([('linear1.weight', tensor([[ 0.6408,  0.3308, -0.1328, -2.3858, -2.5353, -2.2862, -1.0984,  2.9204,
#          -2.6576, -2.6369,  0.1866,  0.1781]])), ('linear1.bias', tensor([0.0785])), ('linear2.weight', tensor([[0.8916]])), ('linear2.bias', tensor([0.0863]))])
# ------------------------------------------------------------------------------------------------------------------------
# Stage: 30
# OrderedDict([('linear1.weight', tensor([[ 0.6408,  0.3308, -0.1328, -2.3858, -2.5353, -2.2862, -1.0984,  2.9204,
#          -2.6576, -2.6369,  0.1866,  0.1781]])), ('linear1.bias', tensor([0.0785])), ('linear2.weight', tensor([[0.8916]])), ('linear2.bias', tensor([0.0863]))])
# alpha= tensor(0.7822, grad_fn=<MinBackward1>)
# beta=  tensor(0.2067, grad_fn=<MaxBackward1>)
#
#
# REGULARIZING MODULE finished: 執行了100次→ An acceptable net that has a preference on weights.
# MATCHING MODULE finished: 執行了100次→ Unacceptable net.
# REORGANIZING MODULE cannot drop the hidden node: 1/1
# REORGANIZING MODULE finished: Acceptable net with the number of hidden nodes= 1
# OrderedDict([('linear1.weight', tensor([[ 0.6175,  0.3197, -0.1329, -2.3295, -2.4791, -2.2300, -1.0422,  2.9203,
#          -2.6014, -2.6341,  0.1865,  0.2001]])), ('linear1.bias', tensor([0.0785])), ('linear2.weight', tensor([[0.8915]])), ('linear2.bias', tensor([0.0862]))])
# ------------------------------------------------------------------------------------------------------------------------
# Stage: 31
# OrderedDict([('linear1.weight', tensor([[ 0.6175,  0.3197, -0.1329, -2.3295, -2.4791, -2.2300, -1.0422,  2.9203,
#          -2.6014, -2.6341,  0.1865,  0.2001]])), ('linear1.bias', tensor([0.0785])), ('linear2.weight', tensor([[0.8915]])), ('linear2.bias', tensor([0.0862]))])
# alpha= tensor(0.7944, grad_fn=<MinBackward1>)
# beta=  tensor(0.2245, grad_fn=<MaxBackward1>)
#
#
# REGULARIZING MODULE finished: 執行了100次→ An acceptable net that has a preference on weights.
# MATCHING MODULE finished: 執行了100次→ Unacceptable net.
# REORGANIZING MODULE cannot drop the hidden node: 1/1
# REORGANIZING MODULE finished: Acceptable net with the number of hidden nodes= 1
# OrderedDict([('linear1.weight', tensor([[ 0.5965,  0.3136, -0.1338, -2.2722, -2.4218, -2.1726, -0.9848,  2.9194,
#          -2.5440, -2.6351,  0.1856,  0.2207]])), ('linear1.bias', tensor([0.0776])), ('linear2.weight', tensor([[0.8906]])), ('linear2.bias', tensor([0.0853]))])
# ------------------------------------------------------------------------------------------------------------------------
# Stage: 32
# OrderedDict([('linear1.weight', tensor([[ 0.5965,  0.3136, -0.1338, -2.2722, -2.4218, -2.1726, -0.9848,  2.9194,
#          -2.5440, -2.6351,  0.1856,  0.2207]])), ('linear1.bias', tensor([0.0776])), ('linear2.weight', tensor([[0.8906]])), ('linear2.bias', tensor([0.0853]))])
# alpha= tensor(0.7600, grad_fn=<MinBackward1>)
# beta=  tensor(0.2415, grad_fn=<MaxBackward1>)
#
#
# REGULARIZING MODULE finished: 執行了100次→ An acceptable net that has a preference on weights.
# MATCHING MODULE finished: 執行了100次→ Unacceptable net.
# REORGANIZING MODULE cannot drop the hidden node: 1/1
# REORGANIZING MODULE finished: Acceptable net with the number of hidden nodes= 1
# OrderedDict([('linear1.weight', tensor([[ 0.5754,  0.3044, -0.1405, -2.2134, -2.3631, -2.1139, -0.9260,  2.9128,
#          -2.4853, -2.6797,  0.1855,  0.2551]])), ('linear1.bias', tensor([0.0829])), ('linear2.weight', tensor([[0.8755]])), ('linear2.bias', tensor([0.0906]))])
# ------------------------------------------------------------------------------------------------------------------------
# Stage: 33
# OrderedDict([('linear1.weight', tensor([[ 0.5754,  0.3044, -0.1405, -2.2134, -2.3631, -2.1139, -0.9260,  2.9128,
#          -2.4853, -2.6797,  0.1855,  0.2551]])), ('linear1.bias', tensor([0.0829])), ('linear2.weight', tensor([[0.8755]])), ('linear2.bias', tensor([0.0906]))])
# alpha= tensor(0.7671, grad_fn=<MinBackward1>)
# beta=  tensor(0.2711, grad_fn=<MaxBackward1>)
#
#
# REGULARIZING MODULE finished: 執行了100次→ An acceptable net that has a preference on weights.
# MATCHING MODULE finished: 執行了100次→ Unacceptable net.
# REORGANIZING MODULE cannot drop the hidden node: 1/1
# REORGANIZING MODULE finished: Acceptable net with the number of hidden nodes= 1
# OrderedDict([('linear1.weight', tensor([[ 0.5439,  0.2729, -0.1769, -2.1509, -2.3006, -2.0514, -0.8636,  2.8889,
#          -2.4228, -2.7420,  0.1774,  0.2879]])), ('linear1.bias', tensor([0.1157])), ('linear2.weight', tensor([[0.8418]])), ('linear2.bias', tensor([0.1234]))])
# ------------------------------------------------------------------------------------------------------------------------
# Stage: 34
# OrderedDict([('linear1.weight', tensor([[ 0.5439,  0.2729, -0.1769, -2.1509, -2.3006, -2.0514, -0.8636,  2.8889,
#          -2.4228, -2.7420,  0.1774,  0.2879]])), ('linear1.bias', tensor([0.1157])), ('linear2.weight', tensor([[0.8418]])), ('linear2.bias', tensor([0.1234]))])
# alpha= tensor(0.7874, grad_fn=<MinBackward1>)
# beta=  tensor(0.3148, grad_fn=<MaxBackward1>)
#
#
# REGULARIZING MODULE finished: 執行了100次→ An acceptable net that has a preference on weights.
# MATCHING MODULE finished: 執行了100次→ Unacceptable net.
# REORGANIZING MODULE cannot drop the hidden node: 1/1
# REORGANIZING MODULE finished: Acceptable net with the number of hidden nodes= 1
# OrderedDict([('linear1.weight', tensor([[ 0.5128,  0.2434, -0.2112, -2.0936, -2.2433, -1.9941, -0.8062,  2.8971,
#          -2.3654, -2.7993,  0.1676,  0.3196]])), ('linear1.bias', tensor([0.1439])), ('linear2.weight', tensor([[0.8116]])), ('linear2.bias', tensor([0.1516]))])
# ------------------------------------------------------------------------------------------------------------------------
# Stage: 35
# OrderedDict([('linear1.weight', tensor([[ 0.5128,  0.2434, -0.2112, -2.0936, -2.2433, -1.9941, -0.8062,  2.8971,
#          -2.3654, -2.7993,  0.1676,  0.3196]])), ('linear1.bias', tensor([0.1439])), ('linear2.weight', tensor([[0.8116]])), ('linear2.bias', tensor([0.1516]))])
# alpha= tensor(0.8039, grad_fn=<MinBackward1>)
# beta=  tensor(0.3496, grad_fn=<MaxBackward1>)
#
#
# REGULARIZING MODULE finished: 執行了100次→ An acceptable net that has a preference on weights.
# MATCHING MODULE finished: 執行了100次→ Unacceptable net.
# REORGANIZING MODULE cannot drop the hidden node: 1/1
# REORGANIZING MODULE finished: Acceptable net with the number of hidden nodes= 1
# OrderedDict([('linear1.weight', tensor([[ 0.5128,  0.2434, -0.2237, -2.0544, -2.2041, -1.9549, -0.7670,  2.8971,
#          -2.3263, -2.8383,  0.1676,  0.3195]])), ('linear1.bias', tensor([0.1439])), ('linear2.weight', tensor([[0.8115]])), ('linear2.bias', tensor([0.1516]))])
# ------------------------------------------------------------------------------------------------------------------------
# Stage: 36
# OrderedDict([('linear1.weight', tensor([[ 0.5128,  0.2434, -0.2237, -2.0544, -2.2041, -1.9549, -0.7670,  2.8971,
#          -2.3263, -2.8383,  0.1676,  0.3195]])), ('linear1.bias', tensor([0.1439])), ('linear2.weight', tensor([[0.8115]])), ('linear2.bias', tensor([0.1516]))])
# alpha= tensor(0.6930, grad_fn=<MinBackward1>)
# beta=  tensor(0.3534, grad_fn=<MaxBackward1>)
#
#
# REGULARIZING MODULE finished: 執行了100次→ An acceptable net that has a preference on weights.
# MATCHING MODULE finished: 執行了100次→ Unacceptable net.
# REORGANIZING MODULE cannot drop the hidden node: 1/1
# REORGANIZING MODULE finished: Acceptable net with the number of hidden nodes= 1
# OrderedDict([('linear1.weight', tensor([[ 0.4697,  0.2022, -0.2625, -1.9857, -2.1354, -1.8862, -0.6983,  2.8615,
#          -2.2575, -2.9070,  0.1559,  0.3541]])), ('linear1.bias', tensor([0.1907])), ('linear2.weight', tensor([[0.7687]])), ('linear2.bias', tensor([0.1984]))])
# ------------------------------------------------------------------------------------------------------------------------
# Stage: 37
# OrderedDict([('linear1.weight', tensor([[ 0.4697,  0.2022, -0.2625, -1.9857, -2.1354, -1.8862, -0.6983,  2.8615,
#          -2.2575, -2.9070,  0.1559,  0.3541]])), ('linear1.bias', tensor([0.1907])), ('linear2.weight', tensor([[0.7687]])), ('linear2.bias', tensor([0.1984]))])
# alpha= tensor(0.7292, grad_fn=<MinBackward1>)
# beta=  tensor(0.4099, grad_fn=<MaxBackward1>)
#
#
# REGULARIZING MODULE finished: 執行了100次→ An acceptable net that has a preference on weights.
# MATCHING MODULE finished: 執行了100次→ Unacceptable net.
# REORGANIZING MODULE cannot drop the hidden node: 1/1
# REORGANIZING MODULE finished: Acceptable net with the number of hidden nodes= 1
# OrderedDict([('linear1.weight', tensor([[ 0.4513,  0.1917, -0.2730, -1.9285, -2.0782, -1.8290, -0.6411,  2.8511,
#          -2.2003, -2.9641,  0.1533,  0.3591]])), ('linear1.bias', tensor([0.2041])), ('linear2.weight', tensor([[0.7582]])), ('linear2.bias', tensor([0.2118]))])
# ------------------------------------------------------------------------------------------------------------------------
# Stage: 38
# OrderedDict([('linear1.weight', tensor([[ 0.4513,  0.1917, -0.2730, -1.9285, -2.0782, -1.8290, -0.6411,  2.8511,
#          -2.2003, -2.9641,  0.1533,  0.3591]])), ('linear1.bias', tensor([0.2041])), ('linear2.weight', tensor([[0.7582]])), ('linear2.bias', tensor([0.2118]))])
# alpha= tensor(0.7445, grad_fn=<MinBackward1>)
# beta=  tensor(0.4328, grad_fn=<MaxBackward1>)
#
#
# REGULARIZING MODULE finished: 執行了100次→ An acceptable net that has a preference on weights.
# MATCHING MODULE finished: 執行了100次→ Unacceptable net.
# REORGANIZING MODULE cannot drop the hidden node: 1/1
# REORGANIZING MODULE finished: Acceptable net with the number of hidden nodes= 1
# OrderedDict([('linear1.weight', tensor([[ 0.4192,  0.1596, -0.2782, -1.8655, -2.0153, -1.7660, -0.5781,  2.8435,
#          -2.1374, -3.0268,  0.1554,  0.3676]])), ('linear1.bias', tensor([0.2240])), ('linear2.weight', tensor([[0.7381]])), ('linear2.bias', tensor([0.2317]))])
# ------------------------------------------------------------------------------------------------------------------------
# Stage: 39
# OrderedDict([('linear1.weight', tensor([[ 0.4192,  0.1596, -0.2782, -1.8655, -2.0153, -1.7660, -0.5781,  2.8435,
#          -2.1374, -3.0268,  0.1554,  0.3676]])), ('linear1.bias', tensor([0.2240])), ('linear2.weight', tensor([[0.7381]])), ('linear2.bias', tensor([0.2317]))])
# alpha= tensor(0.7625, grad_fn=<MinBackward1>)
# beta=  tensor(0.4620, grad_fn=<MaxBackward1>)
#
#
# REGULARIZING MODULE finished: 執行了100次→ An acceptable net that has a preference on weights.
# MATCHING MODULE finished: 執行了100次→ Unacceptable net.
# REORGANIZING MODULE cannot drop the hidden node: 1/1
# REORGANIZING MODULE finished: Acceptable net with the number of hidden nodes= 1
# OrderedDict([('linear1.weight', tensor([[ 0.3791,  0.1253, -0.2969, -1.7967, -1.9465, -1.6972, -0.5093,  2.8292,
#          -2.0686, -3.0953,  0.1596,  0.3767]])), ('linear1.bias', tensor([0.2481])), ('linear2.weight', tensor([[0.7174]])), ('linear2.bias', tensor([0.2559]))])
# ------------------------------------------------------------------------------------------------------------------------
# Stage: 40
# OrderedDict([('linear1.weight', tensor([[ 0.3791,  0.1253, -0.2969, -1.7967, -1.9465, -1.6972, -0.5093,  2.8292,
#          -2.0686, -3.0953,  0.1596,  0.3767]])), ('linear1.bias', tensor([0.2481])), ('linear2.weight', tensor([[0.7174]])), ('linear2.bias', tensor([0.2559]))])
# alpha= tensor(0.7348, grad_fn=<MinBackward1>)
# beta=  tensor(0.4907, grad_fn=<MaxBackward1>)
#
#
# REGULARIZING MODULE finished: 執行了100次→ An acceptable net that has a preference on weights.
# MATCHING MODULE finished: 執行了100次→ Unacceptable net.
# REORGANIZING MODULE cannot drop the hidden node: 1/1
# REORGANIZING MODULE finished: Acceptable net with the number of hidden nodes= 1
# OrderedDict([('linear1.weight', tensor([[ 0.3358,  0.0821, -0.3156, -1.7193, -1.8691, -1.6198, -0.4319,  2.8163,
#          -1.9912, -3.1726,  0.1545,  0.3793]])), ('linear1.bias', tensor([0.2770])), ('linear2.weight', tensor([[0.6947]])), ('linear2.bias', tensor([0.2847]))])
# ------------------------------------------------------------------------------------------------------------------------
# Stage: 41
# OrderedDict([('linear1.weight', tensor([[ 0.3358,  0.0821, -0.3156, -1.7193, -1.8691, -1.6198, -0.4319,  2.8163,
#          -1.9912, -3.1726,  0.1545,  0.3793]])), ('linear1.bias', tensor([0.2770])), ('linear2.weight', tensor([[0.6947]])), ('linear2.bias', tensor([0.2847]))])
# alpha= tensor(0.7539, grad_fn=<MinBackward1>)
# beta=  tensor(0.5182, grad_fn=<MaxBackward1>)
#
#
# REGULARIZING MODULE finished: 執行了100次→ An acceptable net that has a preference on weights.
# MATCHING MODULE finished: 執行了100次→ Unacceptable net.
# REORGANIZING MODULE cannot drop the hidden node: 1/1
# REORGANIZING MODULE finished: Acceptable net with the number of hidden nodes= 1
# OrderedDict([('linear1.weight', tensor([[ 0.2864,  0.0327, -0.3289, -1.6450, -1.7949, -1.5456, -0.3577,  2.8016,
#          -1.9169, -3.2466,  0.1526,  0.3809]])), ('linear1.bias', tensor([0.3098])), ('linear2.weight', tensor([[0.6702]])), ('linear2.bias', tensor([0.3175]))])
# ------------------------------------------------------------------------------------------------------------------------
# Stage: 42
# OrderedDict([('linear1.weight', tensor([[ 0.2864,  0.0327, -0.3289, -1.6450, -1.7949, -1.5456, -0.3577,  2.8016,
#          -1.9169, -3.2466,  0.1526,  0.3809]])), ('linear1.bias', tensor([0.3098])), ('linear2.weight', tensor([[0.6702]])), ('linear2.bias', tensor([0.3175]))])
# alpha= tensor(0.7531, grad_fn=<MinBackward1>)
# beta=  tensor(0.5510, grad_fn=<MaxBackward1>)
#
#
# REGULARIZING MODULE finished: 執行了100次→ An acceptable net that has a preference on weights.
# MATCHING MODULE finished: 執行了100次→ Unacceptable net.
# REORGANIZING MODULE cannot drop the hidden node: 1/1
# REORGANIZING MODULE finished: Acceptable net with the number of hidden nodes= 1
# OrderedDict([('linear1.weight', tensor([[ 0.2581,  0.0043, -0.3285, -1.5738, -1.7237, -1.4744, -0.2865,  2.7970,
#          -1.8458, -3.3177,  0.1564,  0.3848]])), ('linear1.bias', tensor([0.3207])), ('linear2.weight', tensor([[0.6656]])), ('linear2.bias', tensor([0.3284]))])
# ------------------------------------------------------------------------------------------------------------------------
# Stage: 43
# OrderedDict([('linear1.weight', tensor([[ 0.2581,  0.0043, -0.3285, -1.5738, -1.7237, -1.4744, -0.2865,  2.7970,
#          -1.8458, -3.3177,  0.1564,  0.3848]])), ('linear1.bias', tensor([0.3207])), ('linear2.weight', tensor([[0.6656]])), ('linear2.bias', tensor([0.3284]))])
# alpha= tensor(0.7239, grad_fn=<MinBackward1>)
# beta=  tensor(0.5730, grad_fn=<MaxBackward1>)
#
#
# REGULARIZING MODULE finished: 執行了100次→ An acceptable net that has a preference on weights.
# MATCHING MODULE finished: 執行了100次→ Unacceptable net.
# REORGANIZING MODULE cannot drop the hidden node: 1/1
# REORGANIZING MODULE finished: Acceptable net with the number of hidden nodes= 1
# OrderedDict([('linear1.weight', tensor([[ 0.2282, -0.0256, -0.3169, -1.4872, -1.6371, -1.3878, -0.1998,  2.7738,
#          -1.7591, -3.4041,  0.1362,  0.3786]])), ('linear1.bias', tensor([0.3489])), ('linear2.weight', tensor([[0.6337]])), ('linear2.bias', tensor([0.3566]))])
# ------------------------------------------------------------------------------------------------------------------------
# Stage: 44
# OrderedDict([('linear1.weight', tensor([[ 0.2282, -0.0256, -0.3169, -1.4872, -1.6371, -1.3878, -0.1998,  2.7738,
#          -1.7591, -3.4041,  0.1362,  0.3786]])), ('linear1.bias', tensor([0.3489])), ('linear2.weight', tensor([[0.6337]])), ('linear2.bias', tensor([0.3566]))])
# alpha= tensor(0.7471, grad_fn=<MinBackward1>)
# beta=  tensor(0.6060, grad_fn=<MaxBackward1>)
#
#
# REGULARIZING MODULE finished: 執行了100次→ An acceptable net that has a preference on weights.
# MATCHING MODULE finished: 執行了100次→ Unacceptable net.
# REORGANIZING MODULE cannot drop the hidden node: 1/1
# REORGANIZING MODULE finished: Acceptable net with the number of hidden nodes= 1
# OrderedDict([('linear1.weight', tensor([[ 0.1977, -0.0560, -0.3175, -1.4051, -1.5550, -1.3057, -0.1177,  2.7411,
#          -1.6770, -3.4860,  0.1317,  0.3697]])), ('linear1.bias', tensor([0.3833])), ('linear2.weight', tensor([[0.6032]])), ('linear2.bias', tensor([0.3910]))])
# ------------------------------------------------------------------------------------------------------------------------
# Stage: 45
# OrderedDict([('linear1.weight', tensor([[ 0.1977, -0.0560, -0.3175, -1.4051, -1.5550, -1.3057, -0.1177,  2.7411,
#          -1.6770, -3.4860,  0.1317,  0.3697]])), ('linear1.bias', tensor([0.3833])), ('linear2.weight', tensor([[0.6032]])), ('linear2.bias', tensor([0.3910]))])
# alpha= tensor(0.7779, grad_fn=<MinBackward1>)
# beta=  tensor(0.6466, grad_fn=<MaxBackward1>)
#
#
# REGULARIZING MODULE finished: 執行了100次→ An acceptable net that has a preference on weights.
# MATCHING MODULE finished: 執行了100次→ Unacceptable net.
# REORGANIZING MODULE cannot drop the hidden node: 1/1
# REORGANIZING MODULE finished: Acceptable net with the number of hidden nodes= 1
# OrderedDict([('linear1.weight', tensor([[ 0.1794, -0.0744, -0.3225, -1.3239, -1.4739, -1.2245, -0.0366,  2.7228,
#          -1.5959, -3.5670,  0.1414,  0.3626]])), ('linear1.bias', tensor([0.3980])), ('linear2.weight', tensor([[0.5849]])), ('linear2.bias', tensor([0.4057]))])
# ------------------------------------------------------------------------------------------------------------------------
# Stage: 46
# OrderedDict([('linear1.weight', tensor([[ 0.1794, -0.0744, -0.3225, -1.3239, -1.4739, -1.2245, -0.0366,  2.7228,
#          -1.5959, -3.5670,  0.1414,  0.3626]])), ('linear1.bias', tensor([0.3980])), ('linear2.weight', tensor([[0.5849]])), ('linear2.bias', tensor([0.4057]))])
# alpha= tensor(0.7927, grad_fn=<MinBackward1>)
# beta=  tensor(0.6685, grad_fn=<MaxBackward1>)
#
#
# REGULARIZING MODULE finished: 執行了100次→ An acceptable net that has a preference on weights.
# MATCHING MODULE finished: 執行了100次→ Unacceptable net.
# REORGANIZING MODULE cannot drop the hidden node: 1/1
# REORGANIZING MODULE finished: Acceptable net with the number of hidden nodes= 1
# OrderedDict([('linear1.weight', tensor([[ 0.1605, -0.0933, -0.3288, -1.2402, -1.3901, -1.1408,  0.0472,  2.6590,
#          -1.5121, -3.6504,  0.1555,  0.3529]])), ('linear1.bias', tensor([0.4121])), ('linear2.weight', tensor([[0.5660]])), ('linear2.bias', tensor([0.4198]))])
# ------------------------------------------------------------------------------------------------------------------------
# Stage: 47
# OrderedDict([('linear1.weight', tensor([[ 0.1605, -0.0933, -0.3288, -1.2402, -1.3901, -1.1408,  0.0472,  2.6590,
#          -1.5121, -3.6504,  0.1555,  0.3529]])), ('linear1.bias', tensor([0.4121])), ('linear2.weight', tensor([[0.5660]])), ('linear2.bias', tensor([0.4198]))])
# alpha= tensor(0.8032, grad_fn=<MinBackward1>)
# beta=  tensor(0.6881, grad_fn=<MaxBackward1>)
#
#
# REGULARIZING MODULE finished: 執行了100次→ An acceptable net that has a preference on weights.
# MATCHING MODULE finished: 執行了100次→ Unacceptable net.
# REORGANIZING MODULE cannot drop the hidden node: 1/1
# REORGANIZING MODULE finished: Acceptable net with the number of hidden nodes= 1
# ...
# REORGANIZING MODULE cannot drop the hidden node: 33/42
# REGULARIZING MODULE finished: 執行了1次→ An acceptable net that has a preference on weights.
# MATCHING MODULE finished: 執行了100次→ Unacceptable net.
# REORGANIZING MODULE cannot drop the hidden node: 34/42
# REGULARIZING MODULE finished: 執行了1次→ An acceptable net that has a preference on weights.
# MATCHING MODULE finished: 執行了100次→ Unacceptable net.
# REORGANIZING MODULE cannot drop the hidden node: 35/42
# REGULARIZING MODULE finished: 執行了1次→ An acceptable net that has a preference on weights.
# MATCHING MODULE finished: 執行了100次→ Unacceptable net.
# REORGANIZING MODULE cannot drop the hidden node: 36/42
# REGULARIZING MODULE finished: 執行了1次→ An acceptable net that has a preference on weights.
# MATCHING MODULE finished: 執行了100次→ Unacceptable net.
# REORGANIZING MODULE cannot drop the hidden node: 37/42
# REGULARIZING MODULE finished: 執行了1次→ An acceptable net that has a preference on weights.
# MATCHING MODULE finished: 執行了100次→ Unacceptable net.
# REORGANIZING MODULE cannot drop the hidden node: 38/42
# REGULARIZING MODULE finished: 執行了1次→ An acceptable net that has a preference on weights.
# MATCHING MODULE finished: 執行了100次→ Unacceptable net.
# REORGANIZING MODULE cannot drop the hidden node: 39/42
# REGULARIZING MODULE finished: 執行了1次→ An acceptable net that has a preference on weights.
# MATCHING MODULE finished: 執行了100次→ Unacceptable net.
# REORGANIZING MODULE cannot drop the hidden node: 40/42
# REGULARIZING MODULE finished: 執行了1次→ An acceptable net that has a preference on weights.
# MATCHING MODULE finished: 執行了100次→ Unacceptable net.
# REORGANIZING MODULE cannot drop the hidden node: 41/42
# REGULARIZING MODULE finished: 執行了1次→ An acceptable net that has a preference on weights.
# MATCHING MODULE finished: 執行了100次→ Unacceptable net.
# REORGANIZING MODULE cannot drop the hidden node: 42/42
# REORGANIZING MODULE finished: Acceptable net with the number of hidden nodes= 42
# OrderedDict([('linear1.weight', tensor([[ 0.0341, -0.3883, -0.7489, -1.4182, -1.6198, -1.0689, -0.2131,  2.7523,
#          -0.7608, -4.1434,  0.2625,  0.4203],
#         [ 0.5722,  0.0841,  0.2019,  0.5272,  0.5604,  0.2803,  0.5763,  0.9236,
#           0.0776,  0.0434,  0.6180,  0.4567],
#         [ 0.5722,  0.0841,  0.2019,  0.5272,  0.5604,  0.2803,  0.5763,  0.9236,
#           0.0776,  0.0434,  0.6180,  0.4567],
#         [ 0.5722,  0.0841,  0.2019,  0.5272,  0.5604,  0.2803,  0.5763,  0.9236,
#           0.0776,  0.0434,  0.6180,  0.4567],
#         [ 0.6216,  0.5131,  0.0438,  0.6275,  0.5151,  0.0845,  0.0065,  0.2753,
#           0.8650,  0.9335,  0.0961,  0.6793],
#         [ 0.6216,  0.5131,  0.0438,  0.6275,  0.5151,  0.0845,  0.0065,  0.2753,
#           0.8650,  0.9335,  0.0961,  0.6793],
#         [ 0.6216,  0.5131,  0.0438,  0.6275,  0.5151,  0.0845,  0.0065,  0.2753,
#           0.8650,  0.9335,  0.0961,  0.6793],
#         [ 0.3869,  0.4690,  0.3392,  0.6159,  0.0232,  0.0067,  0.6312,  0.0398,
#           0.2782,  0.9809,  0.6524,  0.2627],
#         [ 0.3869,  0.4690,  0.3392,  0.6159,  0.0232,  0.0067,  0.6312,  0.0398,
#           0.2782,  0.9809,  0.6524,  0.2627],
#         [ 0.3869,  0.4690,  0.3392,  0.6159,  0.0232,  0.0067,  0.6312,  0.0398,
#           0.2782,  0.9809,  0.6524,  0.2627],
#         [ 0.3307,  0.3887,  0.7117,  0.5270,  0.8004,  0.5697,  0.7749,  0.5485,
#           0.8624,  0.2214,  0.5722,  0.0551],
#         [ 0.3307,  0.3887,  0.7117,  0.5270,  0.8004,  0.5697,  0.7749,  0.5499,
#           0.8624,  0.2214,  0.5722,  0.0551],
#         [ 0.3307,  0.3887,  0.7117,  0.5270,  0.8004,  0.5697,  0.7749,  0.5480,
#           0.8624,  0.2214,  0.5722,  0.0551],
#         [ 0.9649,  0.8085,  0.0791,  0.0907,  0.7103,  0.3788,  0.3400,  0.3057,
#           0.7232,  0.2929,  0.6257,  0.4883],
#         [ 0.7320,  0.3930,  0.4644,  0.6522,  0.4221,  0.7294,  0.7931,  0.7621,
#           0.7401,  0.4134,  0.3098,  0.1459],
#         [ 0.7320,  0.3930,  0.4644,  0.6522,  0.4221,  0.7294,  0.7931,  0.7621,
#           0.7401,  0.4134,  0.3098,  0.1459],
#         [ 0.7320,  0.3930,  0.4644,  0.6522,  0.4221,  0.7294,  0.7931,  0.7621,
#           0.7401,  0.4134,  0.3098,  0.1459],
#         [ 0.5127,  0.4138,  0.6961,  0.9641,  0.6965,  0.6360,  0.4725,  0.3964,
#           0.2970,  0.7561,  0.1694,  0.3762],
#         [ 0.3985,  0.3527,  0.5168,  0.2194,  0.2679,  0.4482,  0.0225,  0.6540,
#           0.3421,  0.0201,  0.2237,  0.7557],
#         [ 0.3985,  0.3527,  0.5168,  0.2194,  0.2679,  0.4482,  0.0225,  0.6540,
#           0.3421,  0.0201,  0.2237,  0.7557],
#         [ 0.3985,  0.3527,  0.5168,  0.2194,  0.2679,  0.4482,  0.0225,  0.6540,
#           0.3421,  0.0201,  0.2237,  0.7557],
#         [ 0.8088,  0.7978,  0.7200,  0.1087,  0.2094,  0.4174,  0.3740,  0.4343,
#           0.1342,  0.3766,  0.0745,  0.5231],
#         [ 0.8088,  0.7978,  0.7200,  0.1087,  0.2094,  0.4174,  0.3740,  0.4343,
#           0.1342,  0.3766,  0.0745,  0.5231],
#         [ 0.8088,  0.7978,  0.7200,  0.1087,  0.2094,  0.4174,  0.3740,  0.4343,
#           0.1342,  0.3766,  0.0745,  0.5231],
#         [ 0.4078,  0.4159,  0.6398,  0.6330,  0.5443,  0.4038,  0.9439,  0.6482,
#           0.4036,  0.4091,  0.7257,  0.1421],
#         [ 0.4078,  0.4159,  0.6398,  0.6330,  0.5443,  0.4038,  0.9439,  0.6482,
#           0.4036,  0.4091,  0.7257,  0.1421],
#         [ 0.4078,  0.4159,  0.6398,  0.6330,  0.5443,  0.4038,  0.9439,  0.6482,
#           0.4036,  0.4091,  0.7257,  0.1421],
#         [ 0.2219,  0.1133,  0.1591,  0.5815,  0.4941,  0.8822,  0.6094,  0.8981,
#           0.3633,  0.1867,  0.8984,  0.5793],
#         [ 0.2219,  0.1133,  0.1591,  0.5815,  0.4941,  0.8822,  0.6094,  0.8981,
#           0.3633,  0.1867,  0.8984,  0.5793],
#         [ 0.2219,  0.1133,  0.1591,  0.5815,  0.4941,  0.8822,  0.6094,  0.8981,
#           0.3633,  0.1867,  0.8984,  0.5793],
#         [ 0.6592,  0.0930,  0.9450,  0.8416,  0.6182,  0.2773,  0.4564,  0.4697,
#           0.1499,  0.4155,  0.8286,  0.2164],
#         [ 0.6592,  0.0930,  0.9450,  0.8416,  0.6182,  0.2773,  0.4564,  0.4697,
#           0.1499,  0.4155,  0.8286,  0.2164],
#         [ 0.6592,  0.0930,  0.9450,  0.8416,  0.6182,  0.2773,  0.4564,  0.4697,
#           0.1499,  0.4155,  0.8286,  0.2164],
#         [ 0.4264,  0.2578,  0.2002,  0.4415,  0.7928,  0.6337,  0.3012,  0.8571,
#           0.9515,  0.7897,  0.5861,  0.2916],
#         [ 0.4264,  0.2578,  0.2002,  0.4415,  0.7928,  0.6337,  0.3012,  0.8571,
#           0.9515,  0.7897,  0.5861,  0.2916],
#         [ 0.4264,  0.2578,  0.2002,  0.4415,  0.7928,  0.6337,  0.3012,  0.8571,
#           0.9515,  0.7897,  0.5861,  0.2916],
#         [ 0.0341,  0.7028,  0.4995,  0.8117,  0.3224,  0.2815,  0.1100,  0.6973,
#           0.0093,  0.5993,  0.0292,  0.7274],
#         [ 0.0341,  0.7028,  0.4995,  0.8117,  0.3224,  0.2815,  0.1100,  0.6973,
#           0.0093,  0.5993,  0.0292,  0.7274],
#         [ 0.0341,  0.7028,  0.4995,  0.8117,  0.3224,  0.2815,  0.1100,  0.6973,
#           0.0093,  0.5993,  0.0292,  0.7274],
#         [ 0.3182,  0.9912,  0.4815,  0.9413,  0.6546,  0.0766,  0.0568,  0.9152,
#           0.7075,  0.3862,  0.5552,  0.0418],
#         [ 0.3182,  0.9912,  0.4815,  0.9413,  0.6546,  0.0766,  0.0568,  0.9152,
#           0.7075,  0.3862,  0.5552,  0.0418],
#         [ 0.3182,  0.9912,  0.4815,  0.9413,  0.6546,  0.0766,  0.0568,  0.9152,
#           0.7075,  0.3862,  0.5552,  0.0418]])), ('linear1.bias', tensor([ 0.4443, -1.2225, -1.2239, -1.2253, -0.8533, -0.8647, -0.8761, -1.2043,
#         -1.2055, -1.2067, -1.3224, -1.3233, -1.3241, -1.5168, -1.2446, -1.2453,
#         -1.2461, -1.4188, -1.2496, -1.2503, -1.2509, -1.5895, -1.5913, -1.5931,
#         -1.7968, -1.8169, -1.8369, -1.5555, -1.5557, -1.5558, -1.7351, -1.7352,
#         -1.7352, -0.9002, -0.9010, -0.9018, -1.1029, -1.1076, -1.1123, -1.4620,
#         -1.4623, -1.4625])), ('linear2.weight', tensor([[ 9.7245e-01,  1.0986e+02, -2.1971e+02,  1.0986e+02,  1.1858e+01,
#          -2.3715e+01,  1.1858e+01,  7.8966e+01, -1.5793e+02,  7.8966e+01,
#           2.7965e+01, -5.5931e+01,  2.7965e+01,  4.9604e+04,  2.0555e+02,
#          -4.1110e+02,  2.0555e+02,  1.9172e+04,  2.4074e+02, -4.8149e+02,
#           2.4074e+02, -1.1854e+06,  2.3709e+06, -1.1854e+06, -3.7811e+05,
#           7.5623e+05, -3.7811e+05, -5.2623e+07,  1.0525e+08, -5.2623e+07,
#          -5.9761e+06,  1.1952e+07, -5.9761e+06,  1.6935e+03, -3.3869e+03,
#           1.6935e+03,  3.1355e+02, -6.2710e+02,  3.1355e+02, -1.1844e+07,
#           2.3687e+07, -1.1844e+07]])), ('linear2.bias', tensor([0.2741]))])
# ------------------------------------------------------------------------------------------------------------------------
# Stage: 94
# OrderedDict([('linear1.weight', tensor([[ 0.0341, -0.3883, -0.7489, -1.4182, -1.6198, -1.0689, -0.2131,  2.7523,
#          -0.7608, -4.1434,  0.2625,  0.4203],
#         [ 0.5722,  0.0841,  0.2019,  0.5272,  0.5604,  0.2803,  0.5763,  0.9236,
#           0.0776,  0.0434,  0.6180,  0.4567],
#         [ 0.5722,  0.0841,  0.2019,  0.5272,  0.5604,  0.2803,  0.5763,  0.9236,
#           0.0776,  0.0434,  0.6180,  0.4567],
#         [ 0.5722,  0.0841,  0.2019,  0.5272,  0.5604,  0.2803,  0.5763,  0.9236,
#           0.0776,  0.0434,  0.6180,  0.4567],
#         [ 0.6216,  0.5131,  0.0438,  0.6275,  0.5151,  0.0845,  0.0065,  0.2753,
#           0.8650,  0.9335,  0.0961,  0.6793],
#         [ 0.6216,  0.5131,  0.0438,  0.6275,  0.5151,  0.0845,  0.0065,  0.2753,
#           0.8650,  0.9335,  0.0961,  0.6793],
#         [ 0.6216,  0.5131,  0.0438,  0.6275,  0.5151,  0.0845,  0.0065,  0.2753,
#           0.8650,  0.9335,  0.0961,  0.6793],
#         [ 0.3869,  0.4690,  0.3392,  0.6159,  0.0232,  0.0067,  0.6312,  0.0398,
#           0.2782,  0.9809,  0.6524,  0.2627],
#         [ 0.3869,  0.4690,  0.3392,  0.6159,  0.0232,  0.0067,  0.6312,  0.0398,
#           0.2782,  0.9809,  0.6524,  0.2627],
#         [ 0.3869,  0.4690,  0.3392,  0.6159,  0.0232,  0.0067,  0.6312,  0.0398,
#           0.2782,  0.9809,  0.6524,  0.2627],
#         [ 0.3307,  0.3887,  0.7117,  0.5270,  0.8004,  0.5697,  0.7749,  0.5485,
#           0.8624,  0.2214,  0.5722,  0.0551],
#         [ 0.3307,  0.3887,  0.7117,  0.5270,  0.8004,  0.5697,  0.7749,  0.5499,
#           0.8624,  0.2214,  0.5722,  0.0551],
#         [ 0.3307,  0.3887,  0.7117,  0.5270,  0.8004,  0.5697,  0.7749,  0.5480,
#           0.8624,  0.2214,  0.5722,  0.0551],
#         [ 0.9649,  0.8085,  0.0791,  0.0907,  0.7103,  0.3788,  0.3400,  0.3057,
#           0.7232,  0.2929,  0.6257,  0.4883],
#         [ 0.7320,  0.3930,  0.4644,  0.6522,  0.4221,  0.7294,  0.7931,  0.7621,
#           0.7401,  0.4134,  0.3098,  0.1459],
#         [ 0.7320,  0.3930,  0.4644,  0.6522,  0.4221,  0.7294,  0.7931,  0.7621,
#           0.7401,  0.4134,  0.3098,  0.1459],
#         [ 0.7320,  0.3930,  0.4644,  0.6522,  0.4221,  0.7294,  0.7931,  0.7621,
#           0.7401,  0.4134,  0.3098,  0.1459],
#         [ 0.5127,  0.4138,  0.6961,  0.9641,  0.6965,  0.6360,  0.4725,  0.3964,
#           0.2970,  0.7561,  0.1694,  0.3762],
#         [ 0.3985,  0.3527,  0.5168,  0.2194,  0.2679,  0.4482,  0.0225,  0.6540,
#           0.3421,  0.0201,  0.2237,  0.7557],
#         [ 0.3985,  0.3527,  0.5168,  0.2194,  0.2679,  0.4482,  0.0225,  0.6540,
#           0.3421,  0.0201,  0.2237,  0.7557],
#         [ 0.3985,  0.3527,  0.5168,  0.2194,  0.2679,  0.4482,  0.0225,  0.6540,
#           0.3421,  0.0201,  0.2237,  0.7557],
#         [ 0.8088,  0.7978,  0.7200,  0.1087,  0.2094,  0.4174,  0.3740,  0.4343,
#           0.1342,  0.3766,  0.0745,  0.5231],
#         [ 0.8088,  0.7978,  0.7200,  0.1087,  0.2094,  0.4174,  0.3740,  0.4343,
#           0.1342,  0.3766,  0.0745,  0.5231],
#         [ 0.8088,  0.7978,  0.7200,  0.1087,  0.2094,  0.4174,  0.3740,  0.4343,
#           0.1342,  0.3766,  0.0745,  0.5231],
#         [ 0.4078,  0.4159,  0.6398,  0.6330,  0.5443,  0.4038,  0.9439,  0.6482,
#           0.4036,  0.4091,  0.7257,  0.1421],
#         [ 0.4078,  0.4159,  0.6398,  0.6330,  0.5443,  0.4038,  0.9439,  0.6482,
#           0.4036,  0.4091,  0.7257,  0.1421],
#         [ 0.4078,  0.4159,  0.6398,  0.6330,  0.5443,  0.4038,  0.9439,  0.6482,
#           0.4036,  0.4091,  0.7257,  0.1421],
#         [ 0.2219,  0.1133,  0.1591,  0.5815,  0.4941,  0.8822,  0.6094,  0.8981,
#           0.3633,  0.1867,  0.8984,  0.5793],
#         [ 0.2219,  0.1133,  0.1591,  0.5815,  0.4941,  0.8822,  0.6094,  0.8981,
#           0.3633,  0.1867,  0.8984,  0.5793],
#         [ 0.2219,  0.1133,  0.1591,  0.5815,  0.4941,  0.8822,  0.6094,  0.8981,
#           0.3633,  0.1867,  0.8984,  0.5793],
#         [ 0.6592,  0.0930,  0.9450,  0.8416,  0.6182,  0.2773,  0.4564,  0.4697,
#           0.1499,  0.4155,  0.8286,  0.2164],
#         [ 0.6592,  0.0930,  0.9450,  0.8416,  0.6182,  0.2773,  0.4564,  0.4697,
#           0.1499,  0.4155,  0.8286,  0.2164],
#         [ 0.6592,  0.0930,  0.9450,  0.8416,  0.6182,  0.2773,  0.4564,  0.4697,
#           0.1499,  0.4155,  0.8286,  0.2164],
#         [ 0.4264,  0.2578,  0.2002,  0.4415,  0.7928,  0.6337,  0.3012,  0.8571,
#           0.9515,  0.7897,  0.5861,  0.2916],
#         [ 0.4264,  0.2578,  0.2002,  0.4415,  0.7928,  0.6337,  0.3012,  0.8571,
#           0.9515,  0.7897,  0.5861,  0.2916],
#         [ 0.4264,  0.2578,  0.2002,  0.4415,  0.7928,  0.6337,  0.3012,  0.8571,
#           0.9515,  0.7897,  0.5861,  0.2916],
#         [ 0.0341,  0.7028,  0.4995,  0.8117,  0.3224,  0.2815,  0.1100,  0.6973,
#           0.0093,  0.5993,  0.0292,  0.7274],
#         [ 0.0341,  0.7028,  0.4995,  0.8117,  0.3224,  0.2815,  0.1100,  0.6973,
#           0.0093,  0.5993,  0.0292,  0.7274],
#         [ 0.0341,  0.7028,  0.4995,  0.8117,  0.3224,  0.2815,  0.1100,  0.6973,
#           0.0093,  0.5993,  0.0292,  0.7274],
#         [ 0.3182,  0.9912,  0.4815,  0.9413,  0.6546,  0.0766,  0.0568,  0.9152,
#           0.7075,  0.3862,  0.5552,  0.0418],
#         [ 0.3182,  0.9912,  0.4815,  0.9413,  0.6546,  0.0766,  0.0568,  0.9152,
#           0.7075,  0.3862,  0.5552,  0.0418],
#         [ 0.3182,  0.9912,  0.4815,  0.9413,  0.6546,  0.0766,  0.0568,  0.9152,
#           0.7075,  0.3862,  0.5552,  0.0418]])), ('linear1.bias', tensor([ 0.4443, -1.2225, -1.2239, -1.2253, -0.8533, -0.8647, -0.8761, -1.2043,
#         -1.2055, -1.2067, -1.3224, -1.3233, -1.3241, -1.5168, -1.2446, -1.2453,
#         -1.2461, -1.4188, -1.2496, -1.2503, -1.2509, -1.5895, -1.5913, -1.5931,
#         -1.7968, -1.8169, -1.8369, -1.5555, -1.5557, -1.5558, -1.7351, -1.7352,
#         -1.7352, -0.9002, -0.9010, -0.9018, -1.1029, -1.1076, -1.1123, -1.4620,
#         -1.4623, -1.4625])), ('linear2.weight', tensor([[ 9.7245e-01,  1.0986e+02, -2.1971e+02,  1.0986e+02,  1.1858e+01,
#          -2.3715e+01,  1.1858e+01,  7.8966e+01, -1.5793e+02,  7.8966e+01,
#           2.7965e+01, -5.5931e+01,  2.7965e+01,  4.9604e+04,  2.0555e+02,
#          -4.1110e+02,  2.0555e+02,  1.9172e+04,  2.4074e+02, -4.8149e+02,
#           2.4074e+02, -1.1854e+06,  2.3709e+06, -1.1854e+06, -3.7811e+05,
#           7.5623e+05, -3.7811e+05, -5.2623e+07,  1.0525e+08, -5.2623e+07,
#          -5.9761e+06,  1.1952e+07, -5.9761e+06,  1.6935e+03, -3.3869e+03,
#           1.6935e+03,  3.1355e+02, -6.2710e+02,  3.1355e+02, -1.1844e+07,
#           2.3687e+07, -1.1844e+07]])), ('linear2.bias', tensor([0.2741]))])
# alpha= tensor(0.3991, grad_fn=<MinBackward1>)
# beta=  tensor(3.0241, grad_fn=<MaxBackward1>)
#
#
# MATCHING MODULE finished: 執行了100次→ Unacceptable net.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-52d9a84ae265> in <module>
#      85             model = pre_model
#      86             #進入cramming module
# ---> 87             model = cramming(x_current, y_current, model)
#      88             #進入reorganizing module
#      89             model = reorganizing(x_current, y_current, model)
#
# <ipython-input-10-50d80609e57c> in cramming(x, y, model)
#      18         # find a small number: zeta
#      19         zeta = torch.rand(1)
# ---> 20         z_value = (zeta+matmul_subvalue)*(zeta-matmul_subvalue)
#      21         if False not in torch.lt(z_value,0):
#      22             break
#
# KeyboardInterrupt:
